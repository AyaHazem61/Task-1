# %%
n = int(input())
# Out:
# 3

# %%
q = 0
ls = []
for i in range(0,n) :
    ls.append(input().split(" "))
for i in  range(0,n) :
    ct = 0
    for j in range(0,3) :
        ls[i][j] = int(ls[i][j])
        if ls[i][j] == 1 :
            ct += 1
    if ct >= 2 :
        q += 1
print(q)
# Out:
# 1 1 0
# 1 1 1
# 1 0 0
# 2

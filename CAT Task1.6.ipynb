# %%
l1 = input().split(" ")
n = int(l1[0])
k = int(l1[1])
# Out:
# 5 5

# %%
ls = input().split(" ")
for i in range(0,n) :
    ls[i] = int(ls[i])
ct = 0
for i in range(0,n) :
    if ls[i] >= ls[k-1] and ls[i] != 0 :
        ct +=1
print(ct)
# Out:
# 3 2 1 0 0
# 3

# %%
# Out:
# 0

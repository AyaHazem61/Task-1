# %%
n = int(input())
arr = input().split()
for i in range(0,n) :
    arr[i] = int(arr[i])
# Out:
# 5
# 2 3 6 6 5

# %%
m = 6
k = 0
for i in range(0,n) :
    for j in range(i,n) :
        if arr[i] <= arr[j] and arr[j] != m :
            k = arr[j]

# %%
print(k)
# Out:
# 5

# %%
n = int(input())
ls = []
for i in range(0,n) :
    ls.append(input())
# Out:
# 4
# word
# localization
# internationalization
# pneumonoultramicroscopicsilicovolcanoconiosis

# %%
for s in ls :
    if len(s) > 10 :
        print(s[0] , end = '')
        print(len(s)-2,end ='')
        print(s[-1])
    else:
        print(s)
# Out:
# word
# l10n
# i18n
# p43s
